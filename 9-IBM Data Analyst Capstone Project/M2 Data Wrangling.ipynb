# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Data Wrangling Lab**

# %% [markdown]
# ## Objectives

# %% [markdown]
# -   Identify duplicate values in the dataset.
#
# -   Remove duplicate values from the dataset.
#
# -   Identify missing values in the dataset.
#
# -   Impute the missing values in the dataset.
#
# -   Normalize data in the dataset.

# %% [markdown]
# <hr>

# %% [markdown]
# Import pandas module.

# %%
# %pip install pandas

import pandas as pd
# Out:
# Collecting pandas
#   Downloading pandas-2.0.3-cp311-cp311-win_amd64.whl (10.6 MB)
#                                               0.0/10.6 MB ? eta -:--:--
#      ----                                     1.1/10.6 MB 36.7 MB/s eta 0:00:01
#      ----------------                         4.5/10.6 MB 57.6 MB/s eta 0:00:01
#      -------------------------                6.9/10.6 MB 54.9 MB/s eta 0:00:01
#      ------------------------------------     9.7/10.6 MB 56.2 MB/s eta 0:00:01
#      --------------------------------------  10.6/10.6 MB 54.4 MB/s eta 0:00:01
#      --------------------------------------- 10.6/10.6 MB 46.7 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\leonardo.rodriguez\downloads\jupyter\venv\lib\site-packages (from pandas) (2.8.2)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2023.3-py2.py3-none-any.whl (502 kB)
#                                               0.0/502.3 kB ? eta -:--:--
#      ------------------------------------- 502.3/502.3 kB 30.8 MB/s eta 0:00:00
# Collecting tzdata>=2022.1 (from pandas)
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#                                               0.0/341.8 kB ? eta -:--:--
#      ---------------------------------------- 341.8/341.8 kB ? eta 0:00:00
# Collecting numpy>=1.21.0 (from pandas)
#   Downloading numpy-1.25.1-cp311-cp311-win_amd64.whl (15.0 MB)
#                                               0.0/15.0 MB ? eta -:--:--
#      --------                                 3.0/15.0 MB 65.2 MB/s eta 0:00:01
#      --------------                           5.6/15.0 MB 71.7 MB/s eta 0:00:01
#      ----------------------                   8.6/15.0 MB 69.0 MB/s eta 0:00:01
#      --------------------------              10.4/15.0 MB 59.8 MB/s eta 0:00:01
#      -------------------------------         12.0/15.0 MB 59.5 MB/s eta 0:00:01
#      -----------------------------------     13.7/15.0 MB 46.7 MB/s eta 0:00:01
#      --------------------------------------  15.0/15.0 MB 43.7 MB/s eta 0:00:01
#      --------------------------------------- 15.0/15.0 MB 38.6 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in c:\users\leonardo.rodriguez\downloads\jupyter\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-1.25.1 pandas-2.0.3 pytz-2023.3 tzdata-2023.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: c:\Users\Leonardo.Rodriguez\Downloads\Jupyter\venv\Scripts\python.exe -m pip install --upgrade pip

# %% [markdown]
# Load the dataset into a dataframe.

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m1_survey_data.csv")

# %% [markdown]
# ## Finding duplicates

# %% [markdown]
#  Find how many duplicate rows exist in the dataframe.

# %%
# your code goes here
print(df.duplicated().sum())
# Out:
# 154

# %% [markdown]
# ## Removing duplicates

# %% [markdown]
# Remove the duplicate rows from the dataframe.

# %%
# your code goes here
df=df.drop_duplicates()

# %% [markdown]
# Verify if duplicates were actually dropped.

# %%
# your code goes here
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# ## Finding Missing values

# %% [markdown]
# Find the missing values for all columns.

# %%
# your code goes here
print(df.isnull().sum())
# Out:
# Respondent        0
# MainBranch        0
# Hobbyist          0
# OpenSourcer       0
# OpenSource       81
#                ...
# Sexuality       542
# Ethnicity       675
# Dependents      140
# SurveyLength     19
# SurveyEase       14
# Length: 85, dtype: int64

# %% [markdown]
# Find out how many rows are missing in the column 'WorkLoc'

# %%
# your code goes here
print(df["WorkLoc"].isnull().sum())
# Out:
# 32

# %% [markdown]
# ## Imputing missing values

# %% [markdown]
# Find the  value counts for the column WorkLoc.

# %%
# your code goes here
df["WorkLoc"].value_counts()
# Out:
# WorkLoc
# Office                                            6806
# Home                                              3589
# Other place, such as a coworking space or cafe     971
# Name: count, dtype: int64

# %% [markdown]
# Identify the value that is most frequent (majority) in the WorkLoc column.

# %%
#Majority=Office

# %% [markdown]
# Impute (replace) all the empty rows in the column WorkLoc with the value that you have identified as majority.

# %%
# your code goes here
df["WorkLoc"]=df["WorkLoc"].fillna("Office")

# %% [markdown]
# Verify if imputing was successful.

# %%
# your code goes here
print(df["WorkLoc"].isnull().sum())
# Out:
# 0

# %% [markdown]
# ## Normalizing data

# %% [markdown]
# There are two columns in the dataset that talk about compensation.
#
# One is "CompFreq". This column shows how often a developer is paid (Yearly, Monthly, Weekly).
#
# The other is "CompTotal". This column talks about how much the developer is paid per Year, Month, or Week depending upon his/her "CompFreq".
#
# This makes it difficult to compare the total compensation of the developers.
#
# To make comparison of salaries easy, it is necessary to create a new column called 'NormalizedAnnualCompensation' which contains the 'Annual Compensation' irrespective of the 'CompFreq'.

# %% [markdown]
# <hr>

# %% [markdown]
# List out the various categories in the column 'CompFreq'

# %%
# your code goes here
df["CompFreq"].value_counts()
# Out:
# CompFreq
# Yearly     6073
# Monthly    4788
# Weekly      331
# Name: count, dtype: int64

# %% [markdown]
# Create a new column named 'NormalizedAnnualCompensation'. Use the hint given below if needed.

# %% [markdown]
# Double click to see the **Hint**.
#
# <!--
#
# Use the below logic to arrive at the values for the column NormalizedAnnualCompensation.
#
# If the CompFreq is Yearly then use the exising value in CompTotal
# If the CompFreq is Monthly then multiply the value in CompTotal with 12 (months in an year)
# If the CompFreq is Weekly then multiply the value in CompTotal with 52 (weeks in an year)
#
# -->

# %%
# your code goes here
df['NormalizeAnnualCompensation'] = df['CompTotal'] * df['CompFreq'].map({'Yearly': 1.0, 'Monthly': 12.0, 'Weekly': 52.0})
